# %% [markdown]
# **THEORY QUESTION**
#
# **Q1. What is Object-Oriented Programming (OOP)?**
#
# ANS. Object-Oriented Programming (OOP) is a programming paradigm based on the concept of objects. Objects are instances of classes, which are like blueprints that define the attributes (data) and methods (functions) associated with an object. OOP is designed to improve code reusability, scalability, and organization.
#
# Key Concepts of OOP:
#
# 1. Class: A blueprint or template to create objects. It defines the structure and behavior (methods) of the objects.
#
#
# 2. Object: An instance of a class. It represents a real-world entity with properties (attributes) and behaviors (methods).
#
#
# 3. Encapsulation: The practice of bundling data (variables) and methods that operate on the data into a single unit (class) and restricting access to some components using access modifiers (like private, public, protected).
#
#
# 4. Inheritance: The ability of a new class to inherit properties and behavior (methods) from an existing class. This promotes code reusability.
#
#
# 5. Polymorphism: The ability of different classes to be treated as instances of the same class through a common interface. It allows methods to perform differently based on the object calling them.
#
#
# 6. Abstraction: Hiding complex implementation details and showing only the necessary features of an object. It helps in reducing complexity.
#
# **Q2.  What is a class in OOP?**
#
# ANS. In Object-Oriented Programming (OOP), a class is a blueprint or template for creating objects. It defines the attributes (data) and methods (functions) that an object can have.
#
# Think of a class like a blueprint for a house. The blueprint describes the structure (like rooms, doors, windows) but is not the actual house. Similarly, a class defines how an object should behave and what data it should hold, but the object itself is a real-world instance of that class.
#
# Key Components of a Class:
#
# 1. Attributes (Properties): These are variables that store information about the object. For example, in a Car class, attributes can be color, brand, and model.
#
#
# 2. Methods (Functions): These are functions defined inside a class that describe the behavior of the object. For example, a Car class may have a drive() method that makes the car move.
#
# **Q3. What is an object in OOP?**
#
# ANS. In Object-Oriented Programming (OOP), an object is a real-world entity or instance of a class that has:
#
# 1. Attributes (data) - These describe the object's state (like color, name, model).
#
#
# 2. Methods (functions) - These define the object's behavior (like walking, driving, running).
#
# In simple terms, an object is a thing that can perform actions and has some characteristics.
#
#
# **Q4. What is the difference between abstraction and encapsulation?**
#
# ANS. The concepts of Abstraction and Encapsulation are fundamental principles in Object-Oriented Programming (OOP), but they serve different purposes. Here's a clear distinction:
#
# 1. Abstraction:
#
# Definition:
#
# Abstraction is the process of hiding unnecessary details and showing only the essential features of an object.
#
# It helps simplify complex systems by exposing only the relevant functionalities to the user.
#
#
# Purpose:
#
# Reduce complexity by hiding internal implementation.
#
# Focus only on what an object does, not how it does it.
#
#
# 2. Encapsulation:
#
# Definition:
#
# Encapsulation is the process of bundling data (variables) and methods (functions) that operate on the data into a single unit (class) and restricting access to some of the object's components.
#
# It helps protect the internal state of an object from unauthorized access.
#
#
# Purpose:
#
# Protect data from unauthorized modification.
#
# Control access to the internal data through getter and setter methods.
#
#
# **Q5. What are dunder methods in Python?**
#
# ANS. Dunder methods (short for "double underscore" methods) in Python are special methods with names that start and end with double underscores (__). They are also called magic methods or special methods because they provide special functionality to classes and objects in Python.
#
# Why Use Dunder Methods?
#
# Customize behavior of built-in operations like printing, adding, comparing objects, etc.
#
# Enable Python's built-in functions like len(), str(), repr(), etc., to work with your custom objects.
#
# Facilitate operator overloading like +, -, *, etc.
#
# **Q6.Explain the concept of inheritance in OOP?**
#
# ANS. In Object-Oriented Programming (OOP), inheritance is a fundamental concept that allows a new class (called a child class or subclass) to acquire the properties and behaviors (methods) of an existing class (called a parent class or superclass).
#
# The main purpose of inheritance is to promote code reusability and reduce redundancy. Instead of writing the same code multiple times, you can create a base class and reuse its functionalities in derived classes.
#
# Key Concepts of Inheritance:
#
# 1. Parent Class (Superclass): This is the base class that contains common methods and attributes.
#
#
# 2. Child Class (Subclass): This class inherits from the parent class and can have additional methods or override existing ones.
#
#
# 3. Reusability: Code written in the parent class can be reused in the child class.
#
#
# 4. Overriding: The child class can provide its own version of a method that exists in the parent class.
#
#
# 5. Extensibility: You can extend the functionality of an existing class without modifying its original code.
#
#
# Types of Inheritance:
#
# 1. Single Inheritance: One child class inherits from one parent class.
#
#
# 2. Multiple Inheritance: A child class inherits from more than one parent class.
#
#
# 3. Multilevel Inheritance: A class inherits from a class, which in turn inherits from another class.
#
#
# 4. Hierarchical Inheritance: Multiple child classes inherit from a single parent class.
#
#
# 5. Hybrid Inheritance: A combination of two or more types of inheritance.
#
#
# **Q7. What is polymorphism in OOP?**
#
# ANS. Polymorphism is a key concept in Object-Oriented Programming (OOP) that allows objects of different classes to be treated as objects of a common superclass. It enables one interface to represent multiple forms (behaviors). The term Polymorphism is derived from Greek, where poly means many and morph means forms — hence, "many forms".
#
# Key Idea of Polymorphism:
#
# The same function name or operator can be used for different types of objects.
#
# It provides flexibility and maintainability in code.
#
# Types of Polymorphism:
#
# 1. Compile-time Polymorphism (Static Polymorphism): Achieved through method overloading or operator overloading.
#
#
# 2. Run-time Polymorphism (Dynamic Polymorphism): Achieved through method overriding.
#
#
# **Q8. How is encapsulation achieved in Python?**
#
# ANS. Encapsulation is one of the fundamental principles of Object-Oriented Programming (OOP) that refers to bundling the data (variables) and methods (functions) that operate on the data into a single unit (class). It also involves restricting direct access to some of the object's components to ensure controlled modification.
#
# In Python, encapsulation is achieved using:
#
# 1. Access Modifiers (public, protected, private)
#
#
# 2. Getter and Setter methods
#
#
#
# 1. Access Modifiers in Python
#
# Access modifiers define how the class members (variables and methods) can be accessed from outside the class.
#
#
# 2. Public Members
#
# Public members are accessible from anywhere (inside or outside the class).
#
# 3. Protected Members
#
# Protected members are accessible within the class and subclasses. They are prefixed with a single underscore (_). It is more of a convention and not enforced by Python.
#
# 4. Private Members (Encapsulation)
#
# Private members are prefixed with double underscores (__). Python uses name mangling to make it harder to access these variables directly from outside the class.
#
#
#   Why Use Encapsulation?
#
# 1. Data Protection: Prevents unauthorized access and accidental modification of data.
#
#
# 2.  Control: Allows control over how data is modified using getter and setter methods.
#
#
# 3. Improved Maintenance: Makes the code more maintainable and flexible.
#
#
# 4. Hiding Complexity: Hides the internal implementation of the class from the outside.
#
#
# **Q9. What is a constructor in Python?**
#
# ANS. A constructor in Python is a special method used to initialize objects of a class. It is automatically called when an object is created from a class. The primary purpose of a constructor is to initialize the object's attributes (variables) with default or user-defined values.
#
# In Python, the constructor is defined using the special method called _init_().
#
#  Types of Constructors in Python:
#
# 1. Default Constructor: A constructor that does not take any parameters except self.
#
#
# 2. Parameterized Constructor: A constructor that takes parameters to initialize object attributes.
#
#
# **Q10. What are class and static methods in Python?**
#
# ANS. n Python, class methods and static methods are two special types of methods that belong to a class rather than an instance (object). They are primarily used for different purposes and have distinct behaviors. Let's break them down.
#
#  1. Class Methods
#
# A class method is a method that is bound to the class itself, not the instance (object) of the class. It can access and modify class-level variables (attributes) but cannot modify instance-level variables.
#
# How to Define a Class Method
#
# Use the @classmethod decorator.
#
# The first parameter is always cls, which refers to the class itself (similar to self for instance methods).
#
# It can access or modify class-level attributes.
#
#
#  2. Static Methods
#
# A static method is a method that does not depend on the instance or class. It is simply a utility function that logically belongs to the class but does not need access to class or instance-level data.
#
# How to Define a Static Method
#
# Use the @staticmethod decorator.
#
# It does not take self or cls as its first parameter.
#
# It behaves like a regular function but belongs to the class.
#
#
#
# **Q11. What is method overloading in Python?**
#
# ANS. Method Overloading in Python refers to the ability of a class to have multiple methods with the same name but different parameters (number, type, or order of parameters). This allows you to perform different tasks based on the number or type of arguments passed when calling the method.
#
# However, Python does not natively support method overloading like other languages (Java, C++). Instead, Python uses:
#
# 1. Default Arguments
#
#
# 2. Variable-length Arguments (*args and **kwargs) to simulate method overloading.
#
#
# **Q12. What is method overriding in OOP?**
#
# ANS. Method Overriding is an Object-Oriented Programming (OOP) concept where a child (subclass) provides its own specific implementation of a method that is already defined in its parent class (superclass). The method in the child class must have:
#
# The same name as the parent class method.
#
# The same parameters (signature) as the parent class method.
#
# A different functionality (body) from the parent class method.
#
#
#  Why Use Method Overriding?
#
# To customize or extend the behavior of a method in the child class.
#
# To implement runtime polymorphism (dynamic method dispatch).
#
# To ensure that the child class behaves differently than the parent class for the same method.
#
#
#
#  How Method Overriding Works in Python
#
# In Python, Method Overriding happens when:
#
# You define a method in a child class with the same name and signature as the parent class method.
#
# When you call the method from the child class object, Python will execute the overridden method (child class version) instead of the parent class method.
#
# **Q13. What is a property decorator in Python?**
#
# ANS. A property decorator in Python is a built-in decorator (@property) that allows you to define a method in a class but access it like an attribute (without parentheses).
#
# In simple terms:
#
# It encapsulates instance variables (attributes) by controlling access to them.
#
# It helps define getter, setter, and deleter methods in a clean and Pythonic way.
#
# It promotes the concept of Encapsulation (data hiding) in OOP (Object-Oriented Programming).
#
#
#  Why Use a Property Decorator?
#
# 1. Control access to an attribute (like restricting negative age).
#
#
# 2. Add logic when accessing or modifying attributes.
#
#
# 3. Protect internal variables from direct modification.
#
#
# 4. Provide a cleaner and more Pythonic syntax.
#
# **Q14. Why Is Polymorphism Important in OOP?**
#
# ANS. Polymorphism means "many forms". In OOP, polymorphism allows objects of different classes to be treated as objects of a common base class. It enables a single interface (method name) to work with different types of objects.
#
#  Why Is Polymorphism Important in OOP?
#
#  1. Promotes Code Reusability
#
# Polymorphism allows you to write general-purpose code that works with different objects without rewriting the code.
#
# 2. Supports Extensibility (Easy to Add New Features)
#
# Suppose you later add a new shape (Triangle). Without polymorphism, you would need to rewrite the existing code.
#
# 3. Simplifies Code Maintenance
#
# By using polymorphism, you reduce duplicate code. Instead of writing separate functions for each class, you write one function that works with all classes.
#
# 4. Achieves Dynamic (Run-time) Method Binding
#
# In method overriding (run-time polymorphism), Python decides at runtime which method to call based on the object type.
#
# 5. Improves Scalability
#
# Suppose you're building a large application (like a game or a social media app).
#
# Polymorphism allows you to easily add new classes or features without touching the core logic.
#
#
# **Q15. What Is an Abstract Class in Python?**
#
# ANS. An abstract class in Python is a class that cannot be instantiated (you can't create objects from it) and is meant to be inherited by other classes. It serves as a blueprint for other classes by defining common methods that must be implemented by any child class.
#
#
# Why Use an Abstract Class?
#
# Enforce common behavior across related classes.
#
# Provide a template (blueprint) for creating new classes.
#
# Ensure consistency in method names across subclasses.
#
# Promote code reusability and structure in large applications.
#
#
# **Q16. What are the advantages of OOP?**
#
# ANS. Advantages of Object-Oriented Programming (OOP)
#
# 1. Code Reusability (DRY Principle)
#
# OOP promotes code reusability by allowing you to reuse classes and objects without rewriting code.
#
# Once you create a class, you can use it multiple times in different parts of your program.
#
# 2. Encapsulation (Data Hiding)
#
# Encapsulation means hiding internal details of a class and only exposing what is necessary.
#
# It helps protect sensitive data from unauthorized access.
#
#
# 3. Inheritance (Code Reusability and Extension)
#
# Inheritance allows a class to acquire (reuse) properties and methods of another class.
#
# It supports the "is-a" relationship (e.g., Dog is a type of Animal).
#
#
# 4. Polymorphism (Many Forms)
#
# Polymorphism allows one method to have multiple implementations based on the object calling it.
#
# It supports dynamic method binding (run-time polymorphism).
#
#
# 5. Abstraction (Hiding Complexity)
#
# Abstraction means hiding complex logic and only exposing essential features.
#
# It helps users focus on "what an object does" rather than "how it does it."
#
#
# 6. Improved Code Maintainability
#
# OOP makes it easier to update, modify, or fix code without affecting other parts of the system.
#
# Changes made in one class do not break other classes.
#
#
#
# **Q17.What is the difference between a class variable and an instance variable?**
#
# ANS. 1. Class Variable (Static Variable)
#
# Definition:
#
# A class variable is a variable shared among all objects (instances) of a class.
#
# It belongs to the class itself, not to any specific object.
#
# Any change made to a class variable affects all objects of the class.
#
#
# Example of Class Variable:
#
# class Car:
#     wheels = 4  # Class variable
#
#     def _init_(self, brand):
#         self.brand = brand  # Instance variable
#
# car1 = Car("Toyota")
# car2 = Car("Honda")
#
# print(car1.wheels)  # Output: 4
# print(car2.wheels)  # Output: 4
#
# Car.wheels = 5  # Changing class variable
# print(car1.wheels)  # Output: 5
# print(car2.wheels)  # Output: 5
#
# 2. Instance Variable (Object Variable)
#
# Definition:
#
# An instance variable is a variable unique to each object (instance) of a class.
#
# It belongs to the object itself, not the class.
#
# Any change made to an instance variable only affects that specific object.
#
# Example of Instance Variable:
#
# class Car:
#     def _init_(self, brand):
#         self.brand = brand  # Instance variable
#
# car1 = Car("Toyota")
# car2 = Car("Honda")
#
# print(car1.brand)  # Output: Toyota
# print(car2.brand)  # Output: Honda
#
# car1.brand = "Ford"
# print(car1.brand)  # Output: Ford
# print(car2.brand)  # Output: Honda
#
#
# **Q18. What is Multiple Inheritance in Python?**
#
# ANS. Multiple Inheritance is a feature in Python where a class can inherit from more than one parent class (i.e., it can have multiple base classes).
#
# This allows a child class to acquire the properties and methods of multiple parent classes.
#
#
# Syntax of Multiple Inheritance:
#
# class Parent1:
#     # Parent1 class
#     pass
#
# class Parent2:
#     # Parent2 class
#     pass
#
# class Child(Parent1, Parent2):
#     # Child class inheriting from Parent1 and Parent2
#     pass
#
#  The Child class inherits from both Parent1 and Parent2.
#
#
#
#  Example of Multiple Inheritance in Python:
#
#  Example: A Flying Car (Car + Airplane)
#
# class Car:
#     def drive(self):
#         print("Driving on road.")
#
# class Airplane:
#     def fly(self):
#         print("Flying in the sky.")
#
# class FlyingCar(Car, Airplane):
#     pass
#
# vehicle = FlyingCar()
# vehicle.drive()  # Output: Driving on road.
# vehicle.fly()    # Output: Flying in the sky.
#
# **Q19. What is the Purpose of _str() and __repr_() Methods in Python?**
#
# ANS. 1. What is the _str_() Method in Python?
#
#  Definition:
#
# The _str_() method is a built-in special method (dunder method) in Python.
#
# Its primary purpose is to return a human-readable (user-friendly) string representation of an object.
#
# It is called when you use print() or str() on an object.
#
#  Purpose of _str_()
#
# Provide a readable description of the object for end-users.
#
# Focus on user-friendliness, not technical details.
#
#
# 2. What is the _repr_() Method in Python?
#
#  Definition:
#
# The _repr_() method is another built-in special method (dunder method) in Python.
#
# Its primary purpose is to return a formal, technical (developer-friendly) string representation of an object.
#
# This representation should ideally be unambiguous and used for debugging or development purposes.
#
# Purpose of _repr_()
#
# Provide a complete and detailed description of the object (useful for developers).
#
# The string returned by _repr_() should look like valid Python code that can recreate the object.
#
#
# **Q20.  What is the Significance of the super() Function in Python?**
#
# ANS. Definition of super() in Python
#
# The super() function in Python is used to call a method from the parent (base) class in a child (derived) class.
#
# It is commonly used in inheritance to:
#
# 1. Access the parent class’s methods or constructors.
#
#
# 2. Avoid redundant code.
#
#
# 3. Support multiple inheritance.
#
#
# Why Do We Use super()?
#
# 1. Using super() to Call Parent Class Constructor
# 2. Using super() to Call Parent Class Methods
# 3. Using super() in Multiple Inheritance (Diamond Problem)
#
#
# **Q21. What is the significance of the del method in Python?**
#
# ANS. The _del_() method in Python is a special (dunder) method that is called automatically when an object is about to be destroyed.
#
# It is also known as the destructor in Python.
#
# It is used to release resources (such as closing files, database connections, network sockets, etc.) when an object is no longer needed.
#
#
# Purpose of _del_() Method
#
# The main purpose of the _del_() method is to:
#
# 1. Clean up resources (like closing files, network connections, or database connections).
#
#
# 2. Perform final operations before an object is destroyed.
#
#
# 3. Automatically get called when an object is deleted or goes out of scope.
#
#
# When Is the _del_() Method Called?
#
# The _del_() method is automatically called in the following scenarios:
#
# 1. When an object goes out of scope (like the end of a function).
#
#
# 2. When you explicitly delete an object using the del statement.
#
#
# 3. When the Python garbage collector destroys the object (if no reference exists).
#
#
# **Q22. What is the difference between @staticmethod and @classmethod in Python?**
#
# ANS. 1. What Is @staticmethod?
#
# A static method does not depend on the instance (self) or the class (cls).
#
# It behaves like a regular function defined inside a class.
#
# It is mainly used for utility/helper functions.
#
# Example of @staticmethod
#
# class MathOperations:
#
#     @staticmethod
#     def add(a, b):
#         return a + b
#
#     @staticmethod
#     def subtract(a, b):
#         return a - b
#
# # Calling static methods without creating an object
# print(MathOperations.add(5, 3))      # Output: 8
# print(MathOperations.subtract(10, 4)) # Output: 6
#
#
# 2. What Is @classmethod?
#
# A class method is a method that receives the class itself (cls) as its first argument.
#
# It can modify class-level data but cannot access instance-level data (self).
#
# It is often used for:
#
# 1. Factory methods — Methods that create objects in different ways.
#
#
# 2. Modifying class variables.
#
# Example of @classmethod
#
# class Person:
#     species = "Human"
#
#     def _init_(self, name):
#         self.name = name
#
#     @classmethod
#     def change_species(cls, new_species):
#         cls.species = new_species
#
# # Creating an object
# p1 = Person("Alice")
#
# # Changing species using class method
# Person.change_species("Superhuman")
#
# print(p1.species)  # Output: Superhuman
# print(Person.species)  # Output: Superhuman
#
#
#
# **Q23. How does polymorphism work in Python with inheritance?**
#
# ANS. Polymorphism means "many forms".
#
# In Python (and Object-Oriented Programming), polymorphism allows the same function or method to behave differently based on the object (class) that is calling it.
#
# It is heavily used with inheritance, where a child class can override or extend a method of its parent class.
#
#
# Polymorphism Through Method Overriding (Using Inheritance)
#
#  How It Works:
#
# You create a parent class with a method.
#
# Then, you create a child class that overrides the parent class method with a different implementation.
#
# The method name stays the same but behaves differently based on the object type.
#
#
# 2. Polymorphism With Functions (Method Overriding)
#
# You can also use a common function to demonstrate polymorphism.
#
#
# 3. Polymorphism With Built-in Functions
#
# In Python, built-in functions like len(), str(), + operator, etc., also support polymorphism.
#
#
#
# **Q24. What is method chaining in Python OOP?**
#
# ANS. Method Chaining in Python OOP (Object-Oriented Programming) refers to calling multiple methods on the same object in a single line of code.
#
# Each method returns the object itself (self), allowing you to chain multiple method calls together like this:
#
#
# object.method1().method2().method3()
#
# This is often used in builder patterns, data processing, or modifying object states.
#
#
# How Method Chaining Works
#
# To achieve method chaining, each method should return self (the current object).
#
# This allows the next method in the chain to act on the same object.
#
#
# **Q25. What is the purpose of the call method in Python?**
#
# ANS. Definition of _call_() Method
#
# In Python, the _call_() method is a special (dunder) method that allows an object to be called like a regular function.
#
# When you define the _call_() method in a class and then create an object of that class, you can call the object like a function using parentheses ().
#
#
# How _call_() Works in Python
#
# When you create an object and use parentheses () on it, Python automatically calls the _call_() method.
#
# Syntax:
#
#
# class MyClass:
#     def _call_(self, *args, **kwargs):
#         # Code to execute when the object is called

# %%
# **PRACTICAL QUESTIONS**


# Q1. Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog that overrides the speak() method to print "Bark!".

# ANS.

class Animal:
    def speak(self):
        print("This animal makes a sound.")

class Dog(Animal):
    def speak(self):
        print("Bark!")

# Creating instances
animal = Animal()
dog = Dog()

# Calling the speak method
animal.speak()  # Output: This animal makes a sound.
dog.speak()     # Output: Bark!
# Out:
# This animal makes a sound.
# Bark!

# %%
# Q2. Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle from it and implement the area() method in both

# ANS.

# Import the math module to access mathematical functions like pi
import math

# Define a base class called Shape to represent a generic shape with methods for calculating area and perimeter
class Shape:
    # Placeholder method for calculating area (to be implemented in derived classes)
    def calculate_area(self):
        pass

    # Placeholder method for calculating perimeter (to be implemented in derived classes)
    def calculate_perimeter(self):
        pass

# Define a derived class called Circle, which inherits from the Shape class
class Circle(Shape):
    # Initialize the Circle object with a given radius
    def __init__(self, radius):
        self.radius = radius

    # Calculate and return the area of the circle using the formula: π * r^2
    def calculate_area(self):
        return math.pi * self.radius**2

    # Calculate and return the perimeter of the circle using the formula: 2π * r
    def calculate_perimeter(self):
        return 2 * math.pi * self.radius

# Define a derived class called Rectangle, which inherits from the Shape class
class Rectangle(Shape):
    # Initialize the Rectangle object with given length and width
    def __init__(self, length, width):
        self.length = length
        self.width = width

    # Calculate and return the area of the rectangle using the formula: length * width
    def calculate_area(self):
        return self.length * self.width

    # Calculate and return the perimeter of the rectangle using the formula: 2 * (length + width)
    def calculate_perimeter(self):
        return 2 * (self.length + self.width)



# Example usage
# Create a Circle object with a given radius and calculate its area and perimeter
r = 7
circle = Circle(r)
circle_area = circle.calculate_area()
circle_perimeter = circle.calculate_perimeter()

# Print the results for the Circle
print("Radius of the circle:", r)
print("Circle Area:", circle_area)
print("Circle Perimeter:", circle_perimeter)

# Create a Rectangle object with given length and width and calculate its area and perimeter
l = 5
w = 7
rectangle = Rectangle(l, w)
rectangle_area = rectangle.calculate_area()
rectangle_perimeter = rectangle.calculate_perimeter()

# Print the results for the Rectangle
print("\nRectangle: Length =", l, " Width =", w)
print("Rectangle Area:", rectangle_area)
print("Rectangle Perimeter:", rectangle_perimeter)
# Out:
# Radius of the circle: 7
# Circle Area: 153.93804002589985
# Circle Perimeter: 43.982297150257104
#
# Rectangle: Length = 5  Width = 7
# Rectangle Area: 35
# Rectangle Perimeter: 24

# %%
# Q3. Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car and further derive a class ElectricCar that adds a battery attribute.

# ANS.

class Vehicle:
    def _init_(self, vehicle_type):
        self.type = vehicle_type

    def show_type(self):
        print(f"Vehicle Type: {self.type}")

# Derived class from Vehicle
class Car(Vehicle):
    def _init_(self, vehicle_type, brand):
        super()._init_(vehicle_type)
        self.brand = brand

    def show_brand(self):
        print(f"Car Brand: {self.brand}")

# Further derived class from Car
class ElectricCar(Car):
    def __init__(self, vehicle_type, brand, battery_capacity):
        super()._init_(vehicle_type, brand)
        self.battery_capacity = battery_capacity

    def show_battery(self):
        print(f"Battery Capacity: {self.battery_capacity} kWh")

# Creating an object of ElectricCar
tesla = ElectricCar("Electric", "Tesla", 100)

# Accessing methods from all three classes
tesla.show_type()        # Output from Vehicle class
tesla.show_brand()       # Output from Car class
tesla.show_battery()     # Output from ElectricCar class
# Out:
# Vehicle Type: Electric
# Car Brand: Tesla
# Battery Capacity: 100 kWh

# %%
# Q4. Demonstrate polymorphism by creating a base class Bird with a method fly(). Create two derived classes Sparrow and Penguin that override the fly() method.

# ANS.

class Bird:
    def fly(self):
        print("Some birds can fly.")

class Sparrow(Bird):
    def fly(self):
        print("Sparrow can fly high.")

class Penguin(Bird):
    def fly(self):
        print("Penguins cannot fly, they swim.")

# Function to demonstrate polymorphism
def flying_test(bird):
    bird.fly()

# Creating objects of Sparrow and Penguin
sparrow = Sparrow()
penguin = Penguin()

# Calling the fly method using polymorphism
flying_test(sparrow)
flying_test(penguin)
# Out:
# Sparrow can fly high.
# Penguins cannot fly, they swim.

# %%
# Q5. Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes balance and methods to deposit, withdraw, and check balance.

# ANS.

class BankAccount:
    def _init_(self, initial_balance):
        # Private attribute
        self.__balance = initial_balance

    # Method to deposit money
    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount
            print(f"Deposited: ${amount}")
        else:
            print("Invalid deposit amount.")

    # Method to withdraw money
    def withdraw(self, amount):
        if 0 < amount <= self.__balance:
            self.__balance -= amount
            print(f"Withdrew: ${amount}")
        else:
            print("Invalid withdrawal amount or insufficient balance.")

    # Method to check balance
    def check_balance(self):
        print(f"Current Balance: ${self.__balance}")

# Creating an object of BankAccount
account = BankAccount()

# Performing operations
account.deposit(500)
account.withdraw(200)
account.check_balance()

# Trying to access private attribute directly (This will fail)
# print(account.__balance)  # Uncommenting this will raise an AttributeError
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-c7bd6b7782ac> in <cell line: 0>()
#      32
#      33 # Performing operations
# ---> 34 account.deposit(500)
#      35 account.withdraw(200)
#      36 account.check_balance()
#
# <ipython-input-13-c7bd6b7782ac> in deposit(self, amount)
#      11     def deposit(self, amount):
#      12         if amount > 0:
# ---> 13             self.__balance += amount
#      14             print(f"Deposited: ${amount}")
#      15         else:
#
# AttributeError: 'BankAccount' object has no attribute '_BankAccount__balance'

# %%
# Q6. Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar and Piano that implement their own version of play().

# ANS.

class Instrument:
    def play(self):
        print("An instrument is being played.")

class Guitar(Instrument):
    def play(self):
        print("Strumming the guitar.")

class Piano(Instrument):
    def play(self):
        print("Playing the piano.")

# Function to demonstrate runtime polymorphism
def perform(instrument):
    instrument.play()

# Creating objects of Guitar and Piano
guitar = Guitar()
piano = Piano()

# Calling the play method using runtime polymorphism
perform(guitar)  # Output: Strumming the guitar.
perform(piano)   # Output: Playing the piano.
# Out:
# Strumming the guitar.
# Playing the piano.

# %%
# Q7. Create a class MathOperations with a class method add_numbers() to add two numbers and a static method subtract_numbers() to subtract two numbers.

#ANS.

class MathOperations:
    # Class method to add two numbers
    @classmethod
    def add_numbers(cls, a, b):
        return a + b

    # Static method to subtract two numbers
    @staticmethod
    def subtract_numbers(a, b):
        return a - b

# Using the class method without creating an object
sum_result = MathOperations.add_numbers(10, 5)
print(f"Sum: {sum_result}")

# Using the static method without creating an object
difference_result = MathOperations.subtract_numbers(10, 5)
print(f"Difference: {difference_result}")
# Out:
# Sum: 15
# Difference: 5

# %%
# Q8. Implement a class Person with a class method to count the total number of persons created.

# ANS.

class Person:
    # Class variable to count the number of persons created
    total_persons = 0

    def __init__(self, name):
        self.name = name
        Person.total_persons += 1

    # Class method to get the total number of persons created
    @classmethod
    def get_total_persons(cls):
        return cls.total_persons

# Creating instances of Person
person1 = Person("Alice")
person2 = Person("Bob")
person3 = Person("Charlie")

# Getting the total number of persons created using the class method
print(f"Total persons created: {Person.get_total_persons()}")
# Out:
# Total persons created: 3

# %%
# Q9. Write a class Fraction with attributes numerator and denominator. Override the str method to display the fraction as "numerator/denominator".

# ANS.

class Fraction:
    def __init__(self, numerator, denominator):
        self.numerator = numerator
        self.denominator = denominator

    # Overriding the __str__() method to display the fraction
    def __str__(self):
        return f"{self.numerator}/{self.denominator}"

# Creating instances of Fraction
fraction1 = Fraction(3, 4)
fraction2 = Fraction(5, 8)

# Displaying the fractions
print(f"First Fraction: {fraction1}")
print(f"Second Fraction: {fraction2}")
# Out:
# First Fraction: 3/4
# Second Fraction: 5/8

# %%
# Q10. Demonstrate operator overloading by creating a class Vector and overriding the add method to add two vectors.

# ANS.

class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    # Overloading the + operator to add two vectors
    def __add__(self, other):
        new_x = self.x + other.x
        new_y = self.y + other.y
        return Vector(new_x, new_y)

    # Overriding the _str_() method to display the vector
    def __str__(self):
        return f"({self.x}, {self.y})"

# Creating two Vector objects
vector1 = Vector(2, 3)
vector2 = Vector(4, 5)

# Adding the two vectors using the + operator
result = vector1 + vector2

# Displaying the result
print(f"Vector 1: {vector1}")
print(f"Vector 2: {vector2}")
print(f"Resultant Vector: {result}")
# Out:
# Vector 1: (2, 3)
# Vector 2: (4, 5)
# Resultant Vector: (6, 8)

# %%
# Q11. Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is {name} and I am {age} years old."

# ANS.

class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    # Method to greet and display the person's details
    def greet(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old.")

# Creating an object of the Person class
person1 = Person("NAZ", 25)
person2 = Person("BANO", 30)

# Calling the greet method
person1.greet()
person2.greet()
# Out:
# Hello, my name is NAZ and I am 25 years old.
# Hello, my name is BANO and I am 30 years old.

# %%
# Q12. Implement a class Student with attributes name and grades. Create a method average_grade() to compute the average of the grades.

# ANS.

class Student:
    def __init__(self, name, grades):
        self.name = name
        self.grades = grades

    # Method to calculate the average grade
    def average_grade(self):
        if len(self.grades) == 0:
            return 0
        return sum(self.grades) / len(self.grades)

# Creating an object of the Student class
student1 = Student("NAZ", [85, 90, 78, 92])
student2 = Student("BANO", [70, 75, 80, 65])

# Calculating and displaying the average grades
print(f"{student1.name}'s average grade: {student1.average_grade():.2f}")
print(f"{student2.name}'s average grade: {student2.average_grade():.2f}")
# Out:
# NAZ's average grade: 86.25
# BANO's average grade: 72.50

# %%
# Q13. Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the area.

# ANS.

class Rectangle:
    def _init_(self):
        self.length = 0
        self.width = 0

    # Method to set the dimensions of the rectangle
    def set_dimensions(self, length, width):
        self.length = length
        self.width = width

    # Method to calculate the area of the rectangle
    def area(self):
        return self.length * self.width

# Creating an object of the Rectangle class
rect = Rectangle()

# Setting dimensions using set_dimensions() method
rect.set_dimensions(5, 10)

# Calculating and displaying the area
print(f"The area of the rectangle is: {rect.area()}")
# Out:
# The area of the rectangle is: 50

# %%
# Q14. Create a class Employee with a method calculate_salary() that computes the salary based on hours worked and hourly rate. Create a derived class Manager that adds a bonus to the salary.

# ANS.

class Employee:
    def __init__(self, name, hours_worked, hourly_rate):
        self.name = name
        self.hours_worked = hours_worked
        self.hourly_rate = hourly_rate

    # Method to calculate salary based on hours worked and hourly rate
    def calculate_salary(self):
        return self.hours_worked * self.hourly_rate

class Manager(Employee):
    def __init__(self, name, hours_worked, hourly_rate, bonus):
        # Inheriting attributes from the Employee class
        super().__init__(name, hours_worked, hourly_rate)
        self.bonus = bonus

    # Overriding the calculate_salary method to add a bonus
    def calculate_salary(self):
        base_salary = super().calculate_salary()
        return base_salary + self.bonus

# Creating an object of the Employee class
employee = Employee("NAZ", 40, 20)
print(f"{employee.name}'s salary: ${employee.calculate_salary()}")

# Creating an object of the Manager class
manager = Manager("BANO", 40, 30, 500)
print(f"{manager.name}'s salary with bonus: ${manager.calculate_salary()}")
# Out:
# NAZ's salary: $800
# BANO's salary with bonus: $1700

# %%
# Q15. Create a class Product with attributes name, price, and quantity. Implement a method total_price() that calculates the total price of the product.

# ANS.

class Product:
    def __init__(self, name, price, quantity):
        self.name = name
        self.price = price
        self.quantity = quantity

    # Method to calculate the total price of the product
    def total_price(self):
        return self.price * self.quantity

# Creating an object of the Product class
product1 = Product("Laptop", 800, 2)
product2 = Product("Phone", 500, 3)

# Calculating and displaying the total price for each product
print(f"Total price for {product1.quantity} {product1.name}(s): ${product1.total_price()}")
print(f"Total price for {product2.quantity} {product2.name}(s): ${product2.total_price()}")
# Out:
# Total price for 2 Laptop(s): $1600
# Total price for 3 Phone(s): $1500

# %%
# Q16. Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that implement the sound() method.

# ANS.

from abc import ABC, abstractmethod

# Abstract base class
class Animal(ABC):
    @abstractmethod
    def sound(self):
        pass

# Derived class Cow that implements the sound() method
class Cow(Animal):
    def sound(self):
        print("Cow says: Moo!")

# Derived class Sheep that implements the sound() method
class Sheep(Animal):
    def sound(self):
        print("Sheep says: Baa!")

# Creating objects of Cow and Sheep
cow = Cow()
sheep = Sheep()

# Calling the sound() method
cow.sound()
sheep.sound()
# Out:
# Cow says: Moo!
# Sheep says: Baa!

# %%
# Q17. Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that returns a formatted string with the book's details.

# ANS.

class Book:
    def __init__(self, title, author, year_published):
        self.title = title
        self.author = author
        self.year_published = year_published

    # Method to return formatted book information
    def get_book_info(self):
        return f"Title: {self.title}\nAuthor: {self.author}\nYear Published: {self.year_published}"

# Creating objects of the Book class
book1 = Book("To Kill a Mockingbird", "Harper Lee", 1960)
book2 = Book("1984", "George Orwell", 1949)

# Displaying book information
print(book1.get_book_info())
print()
print(book2.get_book_info())
# Out:
# Title: To Kill a Mockingbird
# Author: Harper Lee
# Year Published: 1960
#
# Title: 1984
# Author: George Orwell
# Year Published: 1949

# %%
# Q18. Create a class House with attributes address and price. Create a derived class Mansion that adds an attribute number_of_rooms.

# ANS.

class House:
    def __init__(self, address, price):
        self.address = address
        self.price = price

    # Method to display house details
    def display_info(self):
        print(f"Address: {self.address}")
        print(f"Price: ${self.price}")

# Derived class Mansion that adds an attribute number_of_rooms
class Mansion(House):
    def __init__(self, address, price, number_of_rooms):
        # Inheriting address and price from House class
        super().__init__(address, price)
        self.number_of_rooms = number_of_rooms

    # Overriding display_info() to add room details
    def display_info(self):
        super().display_info()
        print(f"Number of Rooms: {self.number_of_rooms}")

# Creating an object of the House class
house = House("123 Main St", 250000)
print("House Details:")
house.display_info()

print("\nMansion Details:")
# Creating an object of the Mansion class
mansion = Mansion("456 Luxury Ave", 1500000, 10)
mansion.display_info()
# Out:
# House Details:
# Address: 123 Main St
# Price: $250000
#
# Mansion Details:
# Address: 456 Luxury Ave
# Price: $1500000
# Number of Rooms: 10
